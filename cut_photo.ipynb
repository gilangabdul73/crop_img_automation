# %% [markdown]
# # Edit Crop Photos from GDrive

# %% [markdown]
# ### Mounting to Drive or Images Folder

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.chdir('/content/drive/MyDrive/testing_cut_photo')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Crop Images (3x4 Dimension)

# %%
from PIL import Image
import os

INPUT_FOLDER = "/content/drive/MyDrive/testing_cut_photo/poto/day_1"
OUTPUT_FOLDER = "/content/drive/MyDrive/testing_cut_photo/crop_result/day_1"

def crop_to_3x4(image_path, output_path, zoom_factor=0.9, focus_point_x=0.5, focus_point_y=0.4):
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    if not (0.0 < zoom_factor <= 1.0):
        print("ERROR: zoom_factor must be between 0.0 and 1.0 (exclusive of 0).")
        return

    try:
        img = Image.open(image_path)
        original_width, original_height = img.size
        print(f"\nProcessing: {os.path.basename(image_path)}")
        target_ratio = 3.0 / 4.0

        # Calculate the largest possible 3:4 crop dimensions
        if (original_width / original_height) > target_ratio:
            max_crop_height = original_height
            max_crop_width = int(max_crop_height * target_ratio)
        else:
            max_crop_width = original_width
            max_crop_height = int(max_crop_width / target_ratio)

        # Apply the zoom factor
        crop_width = int(max_crop_width * zoom_factor)
        crop_height = int(max_crop_height * zoom_factor)

        if crop_width <= 0 or crop_height <= 0:
            print(f"ERROR: Calculated crop dimensions are too small ({crop_width}x{crop_height}). Adjust zoom_factor.")
            return

        delta_w = original_width - crop_width
        delta_h = original_height - crop_height

        if delta_w < 0 or delta_h < 0:
            print("ERROR: Crop dimensions exceed original image size.")
            return

        left = int(delta_w * focus_point_x)
        top = int(delta_h * focus_point_y)
        right = left + crop_width
        bottom = top + crop_height

        cropped_img = img.crop((left, top, right, bottom))

        # Save output
        save_options = {}
        if img.format in ['JPEG', 'JPG']:
            save_options['quality'] = 100
        elif img.format == 'PNG':
            save_options['optimize'] = True

        cropped_img.save(output_path, **save_options)
        print(f"Saved: {output_path} ({os.path.getsize(output_path)/1024:.2f} KB)\n --------------")

    except FileNotFoundError:
        print(f"ERROR: File not found at {image_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

#  Loop through all images
for filename in os.listdir(INPUT_FOLDER):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(INPUT_FOLDER, filename)
        output_filename = filename.replace("Copy of ", "")
        output_path = os.path.join(OUTPUT_FOLDER, output_filename)

        crop_to_3x4(
            image_path=input_path,
            output_path=output_path,
            zoom_factor=0.9,
            focus_point_x=0.5,
            focus_point_y=0.15
        )
# Out:
# Processing: Copy of AGNIA DINARI SOFA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AGNIA DINARI SOFA.JPG (1346.10 KB)
#  --------------
#
# Processing: Copy of ADRIAN GEOVANNI BAHY.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ADRIAN GEOVANNI BAHY.JPG (1501.09 KB)
#  --------------
#
# Processing: Copy of AFIF RADINATA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AFIF RADINATA.JPG (1244.00 KB)
#  --------------
#
# Processing: Copy of AISYAH HILWA ASSABILLAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AISYAH HILWA ASSABILLAH.JPG (1461.33 KB)
#  --------------
#
# Processing: Copy of AHMED HABIBIE MAIZORA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AHMED HABIBIE MAIZORA.JPG (1460.97 KB)
#  --------------
#
# Processing: Copy of AL-AZIZ KURNIAWAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AL-AZIZ KURNIAWAN.JPG (1373.09 KB)
#  --------------
#
# Processing: Copy of ABDULLOH SA'ID MUKHLIS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ABDULLOH SA'ID MUKHLIS.JPG (1385.97 KB)
#  --------------
#
# Processing: Copy of ALFANSYAH ANDHIYA LUMBAN TOBING.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ALFANSYAH ANDHIYA LUMBAN TOBING.JPG (1303.49 KB)
#  --------------
#
# Processing: Copy of ALFONSO FREDERICK SARAGIH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ALFONSO FREDERICK SARAGIH.JPG (1471.56 KB)
#  --------------
#
# Processing: Copy of ALMIRON SYAFI'I.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ALMIRON SYAFI'I.JPG (1449.60 KB)
#  --------------
#
# Processing: Copy of AMANDA ELSYAHARANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AMANDA ELSYAHARANI.JPG (1725.48 KB)
#  --------------
#
# Processing: Copy of ANDHIKA RAFLY FASA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ANDHIKA RAFLY FASA.JPG (1494.07 KB)
#  --------------
#
# Processing: Copy of ASYAM IRSYAD ZAHIR.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ASYAM IRSYAD ZAHIR.JPG (1326.36 KB)
#  --------------
#
# Processing: Copy of ARBI IKA YULIANTI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ARBI IKA YULIANTI.JPG (1760.70 KB)
#  --------------
#
# Processing: Copy of ANNORA BUDI INTANALINA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ANNORA BUDI INTANALINA.JPG (1647.06 KB)
#  --------------
#
# Processing: Copy of ASER TRYANTA ANUGRAH GINTING.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ASER TRYANTA ANUGRAH GINTING.JPG (1350.02 KB)
#  --------------
#
# Processing: Copy of ARIEL SIGIT ANTONIA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ARIEL SIGIT ANTONIA.JPG (1346.35 KB)
#  --------------
#
# Processing: Copy of ANNISA RAHMA KUSUMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ANNISA RAHMA KUSUMA.JPG (1720.70 KB)
#  --------------
#
# Processing: Copy of ARTIKA SARI DEVI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ARTIKA SARI DEVI.JPG (1805.20 KB)
#  --------------
#
# Processing: Copy of ARYADINATA AKIRA SYADID.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ARYADINATA AKIRA SYADID.JPG (1310.48 KB)
#  --------------
#
# Processing: Copy of ANNISA NUR FARIHA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ANNISA NUR FARIHA.JPG (1622.69 KB)
#  --------------
#
# Processing: Copy of ATHAYA NABILA AZZAHRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ATHAYA NABILA AZZAHRA.JPG (1763.37 KB)
#  --------------
#
# Processing: Copy of ATIYAH NURUNNADHRAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ATIYAH NURUNNADHRAH.JPG (1698.67 KB)
#  --------------
#
# Processing: Copy of BALQIS AMALIA SAFITTRI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/BALQIS AMALIA SAFITTRI.JPG (1468.57 KB)
#  --------------
#
# Processing: Copy of CHALYSCHA FANNY HERNANTYAZ.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/CHALYSCHA FANNY HERNANTYAZ.JPG (1707.50 KB)
#  --------------
#
# Processing: Copy of AUNI ZATI BAYANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AUNI ZATI BAYANI.JPG (1633.49 KB)
#  --------------
#
# Processing: Copy of AZKA AZ ZAHRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AZKA AZ ZAHRA.JPG (1626.97 KB)
#  --------------
#
# Processing: Copy of CHAIRANI PUTRI ALLYSYAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/CHAIRANI PUTRI ALLYSYAH.JPG (1748.39 KB)
#  --------------
#
# Processing: Copy of AVATAR ISLAMI MAAJID.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AVATAR ISLAMI MAAJID.JPG (1213.92 KB)
#  --------------
#
# Processing: Copy of BENING ESTU RAHMAWATI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/BENING ESTU RAHMAWATI.JPG (1435.76 KB)
#  --------------
#
# Processing: Copy of AZRIL RAHMAN SIMAMORA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AZRIL RAHMAN SIMAMORA.JPG (1447.14 KB)
#  --------------
#
# Processing: Copy of AURELIA CARISYA PUTRI'.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/AURELIA CARISYA PUTRI'.JPG (1818.33 KB)
#  --------------
#
# Processing: Copy of CHRISTIAN PANJAITAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/CHRISTIAN PANJAITAN.JPG (1342.22 KB)
#  --------------
#
# Processing: Copy of CHRISTIAN SALOMO VIVALDI PURBA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/CHRISTIAN SALOMO VIVALDI PURBA.JPG (1398.63 KB)
#  --------------
#
# Processing: Copy of CINDY ADELIA SIMBOLON.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/CINDY ADELIA SIMBOLON.JPG (1486.55 KB)
#  --------------
#
# Processing: Copy of DANY IBRAHIMOVIC.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/DANY IBRAHIMOVIC.JPG (1515.29 KB)
#  --------------
#
# Processing: Copy of DAFFENDRA ALFARIDZY.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/DAFFENDRA ALFARIDZY.JPG (1359.30 KB)
#  --------------
#
# Processing: Copy of DANENDRA BELVA ABHIRAMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/DANENDRA BELVA ABHIRAMA.JPG (1284.71 KB)
#  --------------
#
# Processing: Copy of DZAKKI SIROJUDDIN YANUAR.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/DZAKKI SIROJUDDIN YANUAR.JPG (1423.95 KB)
#  --------------
#
# Processing: Copy of DISNAYSILA AULIA PUTRI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/DISNAYSILA AULIA PUTRI.JPG (1613.66 KB)
#  --------------
#
# Processing: Copy of DEHAN AVINO AURISKY AQILA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/DEHAN AVINO AURISKY AQILA.JPG (1484.52 KB)
#  --------------
#
# Processing: Copy of DEVINA WIYANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/DEVINA WIYANI.JPG (1860.63 KB)
#  --------------
#
# Processing: Copy of EGI BASTANTA BRAHMANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/EGI BASTANTA BRAHMANA.JPG (1267.30 KB)
#  --------------
#
# Processing: Copy of ELMY ALVINA ANTIKA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ELMY ALVINA ANTIKA.JPG (1099.72 KB)
#  --------------
#
# Processing: Copy of ELOK DURROH SAABIQOH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ELOK DURROH SAABIQOH.JPG (1549.07 KB)
#  --------------
#
# Processing: Copy of ERTA AYUWANDA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ERTA AYUWANDA.JPG (1505.26 KB)
#  --------------
#
# Processing: Copy of FAISAL AYDIN PERMANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FAISAL AYDIN PERMANA.JPG (1069.94 KB)
#  --------------
#
# Processing: Copy of FAISAL RIJAL MAJID.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FAISAL RIJAL MAJID.JPG (1367.50 KB)
#  --------------
#
# Processing: Copy of FAHRUL FAHRIZI SYAMSUDDIN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FAHRUL FAHRIZI SYAMSUDDIN.JPG (1016.06 KB)
#  --------------
#
# Processing: ABDUL KHOLIQ SYARIFUDIN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ABDUL KHOLIQ SYARIFUDIN.JPG (1465.08 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD HAIKAL.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD HAIKAL.JPG (1267.50 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD FATHURDUKEU BERLIANSYAH NUGROHO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD FATHURDUKEU BERLIANSYAH NUGROHO.JPG (1430.12 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD DAFFA'ALFIANOV.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD DAFFA'ALFIANOV.JPG (1410.09 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD ARFA'I.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD ARFA'I.JPG (1354.05 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD ABDUH QUSYAIRI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD ABDUH QUSYAIRI.JPG (1463.45 KB)
#  --------------
#
# Processing: Copy of MU'AMMAR HISYAM.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MU'AMMAR HISYAM.JPG (1401.32 KB)
#  --------------
#
# Processing: Copy of MOH. SYAFIQ AL GHIFARI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MOH. SYAFIQ AL GHIFARI.JPG (1508.42 KB)
#  --------------
#
# Processing: Copy of MICHAEL TAMBA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MICHAEL TAMBA.JPG (1331.85 KB)
#  --------------
#
# Processing: Copy of MELIA ZAHRA PUSPITA SARI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MELIA ZAHRA PUSPITA SARI.JPG (1617.57 KB)
#  --------------
#
# Processing: Copy of MAY HONEY AMARADANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MAY HONEY AMARADANA.JPG (1599.21 KB)
#  --------------
#
# Processing: Copy of MARSELLA TRIUTAMI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MARSELLA TRIUTAMI.JPG (1694.23 KB)
#  --------------
#
# Processing: Copy of MARIE LUYSA DAMAYANTI SIANIPAR.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MARIE LUYSA DAMAYANTI SIANIPAR.JPG (1513.06 KB)
#  --------------
#
# Processing: Copy of M. DIRAHMAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/M. DIRAHMAN.JPG (1256.75 KB)
#  --------------
#
# Processing: Copy of M. ANUGRAH YASA SYAFLI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/M. ANUGRAH YASA SYAFLI.JPG (1363.05 KB)
#  --------------
#
# Processing: Copy of MARSHINTAULI MAYRLIWANI BR. TAMBUN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MARSHINTAULI MAYRLIWANI BR. TAMBUN.JPG (1393.83 KB)
#  --------------
#
# Processing: Copy of M. ANANDA PUTRA PRATAMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/M. ANANDA PUTRA PRATAMA.JPG (1519.47 KB)
#  --------------
#
# Processing: Copy of M RAAFI' RAHMATULLAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/M RAAFI' RAHMATULLAH.JPG (1154.35 KB)
#  --------------
#
# Processing: Copy of M. AIDI SAFARA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/M. AIDI SAFARA.JPG (1513.14 KB)
#  --------------
#
# Processing: Copy of M. REYHAN FAHREZI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/M. REYHAN FAHREZI.JPG (1327.68 KB)
#  --------------
#
# Processing: Copy of LIVIA AZMI IFANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/LIVIA AZMI IFANI.JPG (1574.01 KB)
#  --------------
#
# Processing: Copy of IBNU RAIHAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/IBNU RAIHAN.JPG (1396.53 KB)
#  --------------
#
# Processing: Copy of LABIBA SETYOFI WISNUMURTI PRATIWIMBA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/LABIBA SETYOFI WISNUMURTI PRATIWIMBA.JPG (1653.99 KB)
#  --------------
#
# Processing: Copy of IZRA HEWIT WIBISONO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/IZRA HEWIT WIBISONO.JPG (1693.68 KB)
#  --------------
#
# Processing: Copy of LISA NOVITA IRIANTO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/LISA NOVITA IRIANTO.JPG (1463.87 KB)
#  --------------
#
# Processing: Copy of ISMAIL TUASIKAL.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ISMAIL TUASIKAL.JPG (1329.93 KB)
#  --------------
#
# Processing: Copy of JOSUA PANGIHUTAN PAKPAHAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/JOSUA PANGIHUTAN PAKPAHAN.JPG (1229.19 KB)
#  --------------
#
# Processing: Copy of LEONY MARCELLA LOLO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/LEONY MARCELLA LOLO.JPG (1435.57 KB)
#  --------------
#
# Processing: Copy of JAN GERRARD RAFANAEL SARAGIH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/JAN GERRARD RAFANAEL SARAGIH.JPG (1326.30 KB)
#  --------------
#
# Processing: Copy of KANAYA ALFATHYANISA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/KANAYA ALFATHYANISA.JPG (1379.75 KB)
#  --------------
#
# Processing: Copy of LILY PUTRI AZZAHRO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/LILY PUTRI AZZAHRO.JPG (1692.21 KB)
#  --------------
#
# Processing: Copy of GABRIEL STEVEN ROYANDHI HUTASOIT.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/GABRIEL STEVEN ROYANDHI HUTASOIT.JPG (1369.56 KB)
#  --------------
#
# Processing: Copy of FIFI ALEYDIA PASHA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FIFI ALEYDIA PASHA.JPG (1770.97 KB)
#  --------------
#
# Processing: Copy of GEMELLY METOLAUFA PRAMUDYA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/GEMELLY METOLAUFA PRAMUDYA.JPG (1513.42 KB)
#  --------------
#
# Processing: Copy of HARUN ILYAS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/HARUN ILYAS.JPG (1391.82 KB)
#  --------------
#
# Processing: Copy of HANUM SETYANINGSIH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/HANUM SETYANINGSIH.JPG (1681.14 KB)
#  --------------
#
# Processing: Copy of HANIFA HERMAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/HANIFA HERMAN.JPG (1562.77 KB)
#  --------------
#
# Processing: Copy of FOTHESA ALYA DEVILYN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FOTHESA ALYA DEVILYN.JPG (1620.94 KB)
#  --------------
#
# Processing: Copy of I MADE KRISNA CAHYANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/I MADE KRISNA CAHYANA.JPG (1428.83 KB)
#  --------------
#
# Processing: Copy of GALUH FITRA RAMADHAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/GALUH FITRA RAMADHAN.JPG (1426.82 KB)
#  --------------
#
# Processing: Copy of HISKIA JULIANTO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/HISKIA JULIANTO.JPG (1300.91 KB)
#  --------------
#
# Processing: Copy of FERREOLA NAINGGOLAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FERREOLA NAINGGOLAN.JPG (1583.92 KB)
#  --------------
#
# Processing: Copy of YUSYARTANIA NOVITAMY.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/YUSYARTANIA NOVITAMY.JPG (1444.40 KB)
#  --------------
#
# Processing: Copy of FARIS RIFQI WINDURINATA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FARIS RIFQI WINDURINATA.JPG (1267.76 KB)
#  --------------
#
# Processing: Copy of FATHAN ADI WICAKSANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FATHAN ADI WICAKSANA.JPG (1409.40 KB)
#  --------------
#
# Processing: Copy of FARAMITHA W. DANIELA APLOEGI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FARAMITHA W. DANIELA APLOEGI.JPG (1345.52 KB)
#  --------------
#
# Processing: Copy of FARHAN RIFQI FIRDAUS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FARHAN RIFQI FIRDAUS.JPG (1327.04 KB)
#  --------------
#
# Processing: Copy of FIDEL BINNITO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FIDEL BINNITO.JPG (1391.48 KB)
#  --------------
#
# Processing: Copy of FAJAR AJIE RASYID.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FAJAR AJIE RASYID.JPG (1435.44 KB)
#  --------------
#
# Processing: Copy of FERDINAN MIKE HUTABARAT.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FERDINAN MIKE HUTABARAT.JPG (1287.43 KB)
#  --------------
#
# Processing: Copy of FAJAR APRILYANTO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/FAJAR APRILYANTO.JPG (1402.57 KB)
#  --------------
#
# Processing: Copy of WIJANG AJI NUGROHO APRIAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/WIJANG AJI NUGROHO APRIAN.JPG (1341.35 KB)
#  --------------
#
# Processing: Copy of TRIANTIKA MARTA BELA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/TRIANTIKA MARTA BELA.JPG (1658.27 KB)
#  --------------
#
# Processing: Copy of YEHEZKIEL FEBRIDO SARAGIH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/YEHEZKIEL FEBRIDO SARAGIH.JPG (1338.56 KB)
#  --------------
#
# Processing: Copy of TRESIA EVELIN NAINGGOLAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/TRESIA EVELIN NAINGGOLAN.JPG (1398.87 KB)
#  --------------
#
# Processing: Copy of VANESA MARGARETH OCTOLIN TAMBUNAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/VANESA MARGARETH OCTOLIN TAMBUNAN.JPG (1266.97 KB)
#  --------------
#
# Processing: Copy of SYIFA RAHMADANI HEMI SYAFITRI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/SYIFA RAHMADANI HEMI SYAFITRI.JPG (1673.53 KB)
#  --------------
#
# Processing: Copy of SYIFA JULIA PUTRI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/SYIFA JULIA PUTRI.JPG (1627.02 KB)
#  --------------
#
# Processing: Copy of TIFARA YSIDORA NARESWARI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/TIFARA YSIDORA NARESWARI.JPG (1327.87 KB)
#  --------------
#
# Processing: Copy of SINOK SALSABILA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/SINOK SALSABILA.JPG (1565.58 KB)
#  --------------
#
# Processing: Copy of SITI ISNAINI SIWITAMI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/SITI ISNAINI SIWITAMI.JPG (1500.71 KB)
#  --------------
#
# Processing: Copy of SYAUQI RIFFAN BAZILLAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/SYAUQI RIFFAN BAZILLAH.JPG (1189.53 KB)
#  --------------
#
# Processing: Copy of SELFI AYU JULIANTI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/SELFI AYU JULIANTI.JPG (1467.52 KB)
#  --------------
#
# Processing: Copy of SITI DIA LESTARI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/SITI DIA LESTARI.JPG (1697.75 KB)
#  --------------
#
# Processing: Copy of SITI NUR ANISA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/SITI NUR ANISA.JPG (1553.92 KB)
#  --------------
#
# Processing: Copy of SABRINA MUTHIA AZ-ZAHRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/SABRINA MUTHIA AZ-ZAHRA.JPG (1619.65 KB)
#  --------------
#
# Processing: Copy of S. ADNAN SIREGAR.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/S. ADNAN SIREGAR.JPG (1332.34 KB)
#  --------------
#
# Processing: Copy of ROYMOND PANDAPOTAN ZIRALUO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/ROYMOND PANDAPOTAN ZIRALUO.JPG (1351.72 KB)
#  --------------
#
# Processing: Copy of RIZKA ASSYIFA NAJWA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/RIZKA ASSYIFA NAJWA.JPG (1568.34 KB)
#  --------------
#
# Processing: Copy of PUTRI NABILAH PAHROZI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/PUTRI NABILAH PAHROZI.JPG (1479.45 KB)
#  --------------
#
# Processing: Copy of REVALINA AZZAHRA RAMADHANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/REVALINA AZZAHRA RAMADHANI.JPG (1656.03 KB)
#  --------------
#
# Processing: Copy of RACHMAT BAHTIAR ZANUAJI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/RACHMAT BAHTIAR ZANUAJI.JPG (1371.04 KB)
#  --------------
#
# Processing: Copy of RIO GALLARDO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/RIO GALLARDO.JPG (1317.26 KB)
#  --------------
#
# Processing: Copy of RASTIANA HAFIDZAH RASYID.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/RASTIANA HAFIDZAH RASYID.JPG (1464.93 KB)
#  --------------
#
# Processing: Copy of RAFIE RABBANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/RAFIE RABBANI.JPG (1322.95 KB)
#  --------------
#
# Processing: Copy of RAINA SYAHIRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/RAINA SYAHIRA.JPG (1636.88 KB)
#  --------------
#
# Processing: Copy of QONITA SAUDAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/QONITA SAUDAH.JPG (1518.21 KB)
#  --------------
#
# Processing: Copy of RISKI RABBHANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/RISKI RABBHANI.JPG (1450.05 KB)
#  --------------
#
# Processing: Copy of PUTRI UMI CHOLIFAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/PUTRI UMI CHOLIFAH.JPG (1493.64 KB)
#  --------------
#
# Processing: Copy of NAYLA SAFINA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/NAYLA SAFINA.JPG (1591.68 KB)
#  --------------
#
# Processing: Copy of NURUL IZZA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/NURUL IZZA.JPG (1415.20 KB)
#  --------------
#
# Processing: Copy of NADHIF ANINDHITA PRAMESWARI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/NADHIF ANINDHITA PRAMESWARI.JPG (1553.95 KB)
#  --------------
#
# Processing: Copy of NADHIFA CHANDYA PUTERI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/NADHIFA CHANDYA PUTERI.JPG (1678.26 KB)
#  --------------
#
# Processing: Copy of NAYLA RIFA SYAVANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/NAYLA RIFA SYAVANA.JPG (1624.75 KB)
#  --------------
#
# Processing: Copy of NICO ORLANDO SINAGA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/NICO ORLANDO SINAGA.JPG (1527.44 KB)
#  --------------
#
# Processing: Copy of PRAJAKA YUDA NATA KUSUMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/PRAJAKA YUDA NATA KUSUMA.JPG (1388.54 KB)
#  --------------
#
# Processing: Copy of PUTRI AULIA RAHMAH HARAHAP.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/PUTRI AULIA RAHMAH HARAHAP.JPG (1572.81 KB)
#  --------------
#
# Processing: Copy of PASHA ANDRIO HIDAYAT.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/PASHA ANDRIO HIDAYAT.JPG (1414.53 KB)
#  --------------
#
# Processing: Copy of NABILA PUTRI INDRIYATNO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/NABILA PUTRI INDRIYATNO.JPG (1522.78 KB)
#  --------------
#
# Processing: Copy of NABILA AZ-ZAHRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/NABILA AZ-ZAHRA.JPG (1755.75 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD TAQI ALMAUDUDI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD TAQI ALMAUDUDI.JPG (961.11 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD HAMZAH ILMA SALAM.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD HAMZAH ILMA SALAM.JPG (1283.55 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD RADITYA PRADIPTA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD RADITYA PRADIPTA.JPG (1502.95 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD RIZKI HANAFI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD RIZKI HANAFI.JPG (1367.21 KB)
#  --------------
#
# Processing: Copy of MUSYAFFA RASYAD FIRDAUS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUSYAFFA RASYAD FIRDAUS.JPG (1269.99 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD RIZQI AL FADILAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD RIZQI AL FADILAH.JPG (1368.85 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD ROYYAN YUSTIO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD ROYYAN YUSTIO.JPG (1353.71 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD RAISKHAN RAFI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD RAISKHAN RAFI.JPG (1229.46 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD IDRIS NUR FATIH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_1/MUHAMMAD IDRIS NUR FATIH.JPG (1348.56 KB)
#  --------------

# %%
from PIL import Image
import os

INPUT_FOLDER = "/content/drive/MyDrive/testing_cut_photo/poto/day_2"
OUTPUT_FOLDER = "/content/drive/MyDrive/testing_cut_photo/crop_result/day_2"

def crop_to_3x4(image_path, output_path, zoom_factor=0.9, focus_point_x=0.5, focus_point_y=0.4):
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    if not (0.0 < zoom_factor <= 1.0):
        print("ERROR: zoom_factor must be between 0.0 and 1.0 (exclusive of 0).")
        return

    try:
        img = Image.open(image_path)
        original_width, original_height = img.size
        print(f"\nProcessing: {os.path.basename(image_path)}")
        # print(f"Original dimensions: {original_width}x{original_height} pixels.")

        target_ratio = 3.0 / 4.0

        # --- Calculate the largest possible 3:4 crop dimensions ---
        if (original_width / original_height) > target_ratio:
            max_crop_height = original_height
            max_crop_width = int(max_crop_height * target_ratio)
        else:
            max_crop_width = original_width
            max_crop_height = int(max_crop_width / target_ratio)

        # --- Apply the zoom factor ---
        crop_width = int(max_crop_width * zoom_factor)
        crop_height = int(max_crop_height * zoom_factor)

        if crop_width <= 0 or crop_height <= 0:
            print(f"ERROR: Calculated crop dimensions are too small ({crop_width}x{crop_height}). Adjust zoom_factor.")
            return

        # print(f"Calculated 3x4 crop area (zoom {zoom_factor:.2f}): {crop_width}x{crop_height} pixels.")

        delta_w = original_width - crop_width
        delta_h = original_height - crop_height

        if delta_w < 0 or delta_h < 0:
            print("ERROR: Crop dimensions exceed original image size.")
            return

        left = int(delta_w * focus_point_x)
        top = int(delta_h * focus_point_y)
        right = left + crop_width
        bottom = top + crop_height

        cropped_img = img.crop((left, top, right, bottom))

        # --- Save output ---
        save_options = {}
        if img.format in ['JPEG', 'JPG']:
            save_options['quality'] = 100
        elif img.format == 'PNG':
            save_options['optimize'] = True

        cropped_img.save(output_path, **save_options)
        print(f"✅ Saved: {output_path} ({os.path.getsize(output_path)/1024:.2f} KB)\n --------------")

    except FileNotFoundError:
        print(f"ERROR: File not found at {image_path}")
    except Exception as e:
        print(f"An error occurred: {e}")

# --- Loop through all images ---
for filename in os.listdir(INPUT_FOLDER):
    if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
        input_path = os.path.join(INPUT_FOLDER, filename)
        # Fix: Use replace() to remove "copy of " from the filename for the output path
        output_filename = filename.replace("Copy of ", "")
        output_path = os.path.join(OUTPUT_FOLDER, output_filename)

        crop_to_3x4(
            image_path=input_path,
            output_path=output_path,
            zoom_factor=0.9,
            focus_point_x=0.5,
            focus_point_y=0.15
        )
# Out:
# Processing: Copy of FERINA NAUFALI NAZIFA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FERINA NAUFALI NAZIFA.JPG (1634.05 KB)
#  --------------
#
# Processing: Copy of FEBRITI YUNDRA PUTRI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FEBRITI YUNDRA PUTRI.JPG (1717.32 KB)
#  --------------
#
# Processing: Copy of FARRELL FARUQH EFENDI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FARRELL FARUQH EFENDI.JPG (1306.34 KB)
#  --------------
#
# Processing: Copy of FARISHA ISNAYA HUDA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FARISHA ISNAYA HUDA.JPG (1431.35 KB)
#  --------------
#
# Processing: Copy of FAREL SEHAN RAMADHANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FAREL SEHAN RAMADHANI.JPG (1479.34 KB)
#  --------------
#
# Processing: Copy of FAIQ RIDHO FAUZILA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FAIQ RIDHO FAUZILA.JPG (1331.95 KB)
#  --------------
#
# Processing: Copy of ESTHER RENATA BLESSANDRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ESTHER RENATA BLESSANDRA.JPG (1438.19 KB)
#  --------------
#
# Processing: Copy of ERA ASTA LINI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ERA ASTA LINI.JPG (1582.74 KB)
#  --------------
#
# Processing: Copy of ZULFA QURROTA'AINI AFANIN NISAK.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ZULFA QURROTA'AINI AFANIN NISAK.JPG (1636.56 KB)
#  --------------
#
# Processing: Copy of ENIK NAVIDA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ENIK NAVIDA.JPG (1622.49 KB)
#  --------------
#
# Processing: Copy of AFRIZAL KINAYUNG AURA AQILAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AFRIZAL KINAYUNG AURA AQILAN.JPG (1449.45 KB)
#  --------------
#
# Processing: Copy of AINIYYAH NUR ALIFFAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AINIYYAH NUR ALIFFAH.JPG (1612.06 KB)
#  --------------
#
# Processing: Copy of ADELIA MARIA SIBARANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ADELIA MARIA SIBARANI.JPG (1574.87 KB)
#  --------------
#
# Processing: Copy of ADNAN CAHYA RAMDHANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ADNAN CAHYA RAMDHANI.JPG (1432.11 KB)
#  --------------
#
# Processing: Copy of AISAFINA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AISAFINA.JPG (1605.41 KB)
#  --------------
#
# Processing: Copy of ADINDA NATASYA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ADINDA NATASYA.JPG (1516.34 KB)
#  --------------
#
# Processing: Copy of AHMAD FAISAL DWI SISWANTO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AHMAD FAISAL DWI SISWANTO.JPG (1474.90 KB)
#  --------------
#
# Processing: Copy of ADAM TARUNA WIBOWO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ADAM TARUNA WIBOWO.JPG (1392.18 KB)
#  --------------
#
# Processing: Copy of AHMAD NURIL FALAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AHMAD NURIL FALAH.JPG (1133.40 KB)
#  --------------
#
# Processing: Copy of AINAYA NURUL AZKIYA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AINAYA NURUL AZKIYA.JPG (1533.86 KB)
#  --------------
#
# Processing: Copy of ALYA MAULIDINA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ALYA MAULIDINA.JPG (1588.62 KB)
#  --------------
#
# Processing: Copy of ALYA DHIYA ROSYA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ALYA DHIYA ROSYA.JPG (1528.07 KB)
#  --------------
#
# Processing: Copy of ALEXSANDRA GRACELANIS LASE.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ALEXSANDRA GRACELANIS LASE.JPG (1527.76 KB)
#  --------------
#
# Processing: Copy of AJI DWIANSYAH BASRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AJI DWIANSYAH BASRA.JPG (1450.31 KB)
#  --------------
#
# Processing: Copy of AISYAH SAFA RIANTI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AISYAH SAFA RIANTI.JPG (1803.30 KB)
#  --------------
#
# Processing: Copy of ALDA PERTIWI HADIANTONI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ALDA PERTIWI HADIANTONI.JPG (1748.23 KB)
#  --------------
#
# Processing: Copy of ALFIN DZAKWAN FADHILLA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ALFIN DZAKWAN FADHILLA.JPG (1381.21 KB)
#  --------------
#
# Processing: Copy of ALESSA TISAHRA KARTIKA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ALESSA TISAHRA KARTIKA.JPG (1547.17 KB)
#  --------------
#
# Processing: Copy of AKMAL NUR FAIZ.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AKMAL NUR FAIZ.JPG (1468.05 KB)
#  --------------
#
# Processing: Copy of AISYAH DIFA RAMADHANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AISYAH DIFA RAMADHANI.JPG (1646.31 KB)
#  --------------
#
# Processing: Copy of ANDI ANUGRAH ALIF SAPUTRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ANDI ANUGRAH ALIF SAPUTRA.JPG (1455.37 KB)
#  --------------
#
# Processing: Copy of ANGGUN MUTIARA AHMAD.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ANGGUN MUTIARA AHMAD.JPG (1730.33 KB)
#  --------------
#
# Processing: Copy of ALYA RAMADHAN HENDRI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ALYA RAMADHAN HENDRI.JPG (1553.07 KB)
#  --------------
#
# Processing: Copy of ANDINI MAULIDIYA TSANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ANDINI MAULIDIYA TSANI.JPG (1772.39 KB)
#  --------------
#
# Processing: Copy of AMALIYA RASYIDA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AMALIYA RASYIDA.JPG (1742.83 KB)
#  --------------
#
# Processing: Copy of ARIS KURNIAWAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ARIS KURNIAWAN.JPG (1281.70 KB)
#  --------------
#
# Processing: Copy of ARMANDYTA BUNGA NACITA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ARMANDYTA BUNGA NACITA.JPG (1528.11 KB)
#  --------------
#
# Processing: Copy of ANGGRAYNI GRACE MARGARETH PURBA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ANGGRAYNI GRACE MARGARETH PURBA.JPG (1476.04 KB)
#  --------------
#
# Processing: Copy of ANNISA RAHAYU HSB.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ANNISA RAHAYU HSB.JPG (1634.39 KB)
#  --------------
#
# Processing: Copy of AMAIKA DEPPI CAHAYANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AMAIKA DEPPI CAHAYANI.JPG (1631.19 KB)
#  --------------
#
# Processing: Copy of CHRISTINE DEVITA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/CHRISTINE DEVITA.JPG (1444.64 KB)
#  --------------
#
# Processing: Copy of BUGAR MUHAMMAD DZIKRULLAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/BUGAR MUHAMMAD DZIKRULLAH.JPG (1232.01 KB)
#  --------------
#
# Processing: Copy of CHIKA FRANSISKA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/CHIKA FRANSISKA.JPG (1464.93 KB)
#  --------------
#
# Processing: Copy of CICILIA NABILA DWI ASTUTI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/CICILIA NABILA DWI ASTUTI.JPG (1377.35 KB)
#  --------------
#
# Processing: Copy of AZZAHRA DAMARJATI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/AZZAHRA DAMARJATI.JPG (1597.85 KB)
#  --------------
#
# Processing: Copy of CHELSI CAMORANESI SILABAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/CHELSI CAMORANESI SILABAN.JPG (1433.15 KB)
#  --------------
#
# Processing: Copy of B. ALFIAN FIRMANSYAH DAULAY.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/B. ALFIAN FIRMANSYAH DAULAY.JPG (1240.33 KB)
#  --------------
#
# Processing: Copy of CHRISTIAN LEO PANJAITAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/CHRISTIAN LEO PANJAITAN.JPG (1303.28 KB)
#  --------------
#
# Processing: Copy of ATHAYA NURMA SALSABILA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ATHAYA NURMA SALSABILA.JPG (1658.26 KB)
#  --------------
#
# Processing: Copy of CHELSEA TESALONIKA SITEPU.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/CHELSEA TESALONIKA SITEPU.JPG (1386.95 KB)
#  --------------
#
# Processing: Copy of ELSI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ELSI.JPG (1676.53 KB)
#  --------------
#
# Processing: Copy of CUT SYIFA ZAHRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/CUT SYIFA ZAHRA.JPG (1705.85 KB)
#  --------------
#
# Processing: Copy of DIMAS YULIA SAPUTRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/DIMAS YULIA SAPUTRA.JPG (1480.78 KB)
#  --------------
#
# Processing: Copy of DOBIES AZKA DENANEER ISNOR.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/DOBIES AZKA DENANEER ISNOR.JPG (1424.28 KB)
#  --------------
#
# Processing: Copy of CUT ATIKAH RAMADHANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/CUT ATIKAH RAMADHANI.JPG (1679.07 KB)
#  --------------
#
# Processing: Copy of DEDE AINUNZORA ARLIN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/DEDE AINUNZORA ARLIN.JPG (1621.27 KB)
#  --------------
#
# Processing: Copy of DILLA NAISYILA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/DILLA NAISYILA.JPG (1406.59 KB)
#  --------------
#
# Processing: Copy of DINTASKIYYA IQNIFFARENA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/DINTASKIYYA IQNIFFARENA.JPG (1605.01 KB)
#  --------------
#
# Processing: Copy of CYRIANI NEUMAN REBO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/CYRIANI NEUMAN REBO.JPG (1682.34 KB)
#  --------------
#
# Processing: Copy of DANIEL HATORANGAN NATALIUS SIMBOLON.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/DANIEL HATORANGAN NATALIUS SIMBOLON.JPG (1208.00 KB)
#  --------------
#
# Processing: Copy of HASBI ISFHANDIARY.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/HASBI ISFHANDIARY.JPG (1031.81 KB)
#  --------------
#
# Processing: Copy of HANUN SHIYAMI UMMI ATIQOH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/HANUN SHIYAMI UMMI ATIQOH.JPG (1729.63 KB)
#  --------------
#
# Processing: Copy of HANUN SAFA NUR KAMILAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/HANUN SAFA NUR KAMILAH.JPG (1696.92 KB)
#  --------------
#
# Processing: Copy of HANA MUFIDAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/HANA MUFIDAH.JPG (1587.02 KB)
#  --------------
#
# Processing: Copy of HALIMAH FITRI LUBIS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/HALIMAH FITRI LUBIS.JPG (1636.77 KB)
#  --------------
#
# Processing: Copy of GWEN STEFANNY PATTIRUHU.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/GWEN STEFANNY PATTIRUHU.JPG (1519.46 KB)
#  --------------
#
# Processing: Copy of GRESIA SONYA SINAGA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/GRESIA SONYA SINAGA.JPG (1405.30 KB)
#  --------------
#
# Processing: Copy of GRACE NATHALY DESRIAN SOLIN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/GRACE NATHALY DESRIAN SOLIN.JPG (1530.88 KB)
#  --------------
#
# Processing: Copy of GLORY THERESA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/GLORY THERESA.JPG (1473.16 KB)
#  --------------
#
# Processing: Copy of GIOVANNI SINAGA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/GIOVANNI SINAGA.JPG (1376.28 KB)
#  --------------
#
# Processing: Copy of FINDO ROMADHON.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FINDO ROMADHON.JPG (1524.54 KB)
#  --------------
#
# Processing: Copy of FLORENSIUS YOAN SARBEL.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FLORENSIUS YOAN SARBEL.JPG (1481.33 KB)
#  --------------
#
# Processing: Copy of FIDYAH AFIFAH AZIS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FIDYAH AFIFAH AZIS.JPG (1627.47 KB)
#  --------------
#
# Processing: Copy of FLORA DAMAIYANTI LUBIS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FLORA DAMAIYANTI LUBIS.JPG (1228.27 KB)
#  --------------
#
# Processing: Copy of GAIZKA MULYA RAHMAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/GAIZKA MULYA RAHMAN.JPG (1398.06 KB)
#  --------------
#
# Processing: Copy of GABRIEL FERNANDEZ LUMBANTORUAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/GABRIEL FERNANDEZ LUMBANTORUAN.JPG (1143.57 KB)
#  --------------
#
# Processing: Copy of FIKRI PUTRA PRATAMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FIKRI PUTRA PRATAMA.JPG (1381.72 KB)
#  --------------
#
# Processing: Copy of FITRIANTO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FITRIANTO.JPG (1379.47 KB)
#  --------------
#
# Processing: Copy of GEDE ESA GITA ANANDA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/GEDE ESA GITA ANANDA.JPG (1374.11 KB)
#  --------------
#
# Processing: Copy of FIRDAUS SOFIAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/FIRDAUS SOFIAN.JPG (1181.28 KB)
#  --------------
#
# Processing: Copy of IRENE DELAROSA SITUMORANG.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/IRENE DELAROSA SITUMORANG.JPG (1401.07 KB)
#  --------------
#
# Processing: Copy of KANITA DIANASTI AULIA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/KANITA DIANASTI AULIA.JPG (1768.00 KB)
#  --------------
#
# Processing: Copy of KARISMA YULIS DAMAYANTI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/KARISMA YULIS DAMAYANTI.JPG (1721.66 KB)
#  --------------
#
# Processing: Copy of KESHA NAUFAL RAFID.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/KESHA NAUFAL RAFID.JPG (1487.99 KB)
#  --------------
#
# Processing: Copy of KADEK DESY SITA DEWI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/KADEK DESY SITA DEWI.JPG (1343.13 KB)
#  --------------
#
# Processing: Copy of JOEL OSTEEN MANIHURUK.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/JOEL OSTEEN MANIHURUK.JPG (1065.07 KB)
#  --------------
#
# Processing: Copy of JUAN PALLERMO ALFARIZH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/JUAN PALLERMO ALFARIZH.JPG (1278.52 KB)
#  --------------
#
# Processing: Copy of ISQIANAH REZEQIA MULYAWATI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ISQIANAH REZEQIA MULYAWATI.JPG (1701.79 KB)
#  --------------
#
# Processing: Copy of JORDAN ALI LAKSANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/JORDAN ALI LAKSANA.JPG (1357.42 KB)
#  --------------
#
# Processing: Copy of JAY PREDYTA MELIALA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/JAY PREDYTA MELIALA.JPG (1191.99 KB)
#  --------------
#
# Processing: Copy of INAZ ZARWA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/INAZ ZARWA.JPG (1668.55 KB)
#  --------------
#
# Processing: Copy of IKBAL SETIAWAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/IKBAL SETIAWAN.JPG (1314.94 KB)
#  --------------
#
# Processing: Copy of I WAYAN BAYU WANGSA SATYAWAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/I WAYAN BAYU WANGSA SATYAWAN.JPG (1426.30 KB)
#  --------------
#
# Processing: Copy of INDRAYANA YAHYA SAPUTRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/INDRAYANA YAHYA SAPUTRA.JPG (1266.34 KB)
#  --------------
#
# Processing: Copy of IFTITAKH PUTRI ISLAMI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/IFTITAKH PUTRI ISLAMI.JPG (1769.84 KB)
#  --------------
#
# Processing: Copy of HUSNA SAVANAH SYAKIEB.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/HUSNA SAVANAH SYAKIEB.JPG (1391.63 KB)
#  --------------
#
# Processing: Copy of IBRAHIM L SA JAVANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/IBRAHIM L SA JAVANA.JPG (1402.73 KB)
#  --------------
#
# Processing: Copy of I GEDE JULIANA RAGA SAPUTRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/I GEDE JULIANA RAGA SAPUTRA.JPG (1307.41 KB)
#  --------------
#
# Processing: Copy of IDA BAGUS PUTU ISA MAHESWARA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/IDA BAGUS PUTU ISA MAHESWARA.JPG (1209.72 KB)
#  --------------
#
# Processing: Copy of HAURA ATHIFAH MAWARDI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/HAURA ATHIFAH MAWARDI.JPG (1628.47 KB)
#  --------------
#
# Processing: Copy of MUTIARA ELISYA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUTIARA ELISYA.JPG (1535.75 KB)
#  --------------
#
# Processing: Copy of MUNIFA PERMATASARI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUNIFA PERMATASARI.JPG (1599.61 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD TEGUH SATRIO ERNALENDRO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMMAD TEGUH SATRIO ERNALENDRO.JPG (1225.99 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD RIZQY PUTRA PRATAMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMMAD RIZQY PUTRA PRATAMA.JPG (1298.72 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD RAKISH RIDWANSYAH PUTRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMMAD RAKISH RIDWANSYAH PUTRA.JPG (1314.74 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD RAKI' DHAIFULLAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMMAD RAKI' DHAIFULLAH.JPG (1429.02 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD NIZAR MUZAKKY.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMMAD NIZAR MUZAKKY.JPG (1241.23 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD IKHSAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMMAD IKHSAN.JPG (1344.43 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD FADHIL ILYAS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMMAD FADHIL ILYAS.JPG (1288.54 KB)
#  --------------
#
# Processing: Copy of MUHAMMAD DAVIN FIRJA RAYHAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMMAD DAVIN FIRJA RAYHAN.JPG (1208.59 KB)
#  --------------
#
# Processing: Copy of MICHELIA KIRANA ARUNDATI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MICHELIA KIRANA ARUNDATI.JPG (1627.66 KB)
#  --------------
#
# Processing: Copy of MUHAMAD NUR KHADZIK FAUZI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMAD NUR KHADZIK FAUZI.JPG (1313.09 KB)
#  --------------
#
# Processing: Copy of MAULUDIN SATRYAWAN AHMAD.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MAULUDIN SATRYAWAN AHMAD.JPG (1238.01 KB)
#  --------------
#
# Processing: Copy of MAYONI IMANINGTYAS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MAYONI IMANINGTYAS.JPG (1659.25 KB)
#  --------------
#
# Processing: Copy of MUHAMAD RANGGA ALDIYAN PASHA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MUHAMAD RANGGA ALDIYAN PASHA.JPG (1359.71 KB)
#  --------------
#
# Processing: Copy of MANHA SANIKA ZARIN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MANHA SANIKA ZARIN.JPG (1652.37 KB)
#  --------------
#
# Processing: Copy of MOTIQ MORENTA YAKANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MOTIQ MORENTA YAKANI.JPG (1687.26 KB)
#  --------------
#
# Processing: Copy of MARSA BAGUS PERMANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MARSA BAGUS PERMANA.JPG (1448.33 KB)
#  --------------
#
# Processing: Copy of MAURENT.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MAURENT.JPG (1658.45 KB)
#  --------------
#
# Processing: Copy of MARIA ANASTASYA BR SINAGA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/MARIA ANASTASYA BR SINAGA.JPG (1456.05 KB)
#  --------------
#
# Processing: Copy of M. RIFKY NAUFAL ARUF.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/M. RIFKY NAUFAL ARUF.JPG (1408.91 KB)
#  --------------
#
# Processing: Copy of M. ABYAZ AKHTAR DANAITRA SANJAYA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/M. ABYAZ AKHTAR DANAITRA SANJAYA.JPG (1137.29 KB)
#  --------------
#
# Processing: Copy of KOMANG TRI DANA WIDIARTA KUSUMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/KOMANG TRI DANA WIDIARTA KUSUMA.JPG (1368.14 KB)
#  --------------
#
# Processing: Copy of M RAFIQ HARIRI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/M RAFIQ HARIRI.JPG (1115.54 KB)
#  --------------
#
# Processing: Copy of LOISA LIMBONG.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/LOISA LIMBONG.JPG (1340.54 KB)
#  --------------
#
# Processing: Copy of LINTANG LUCKY RAMADHANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/LINTANG LUCKY RAMADHANI.JPG (1614.35 KB)
#  --------------
#
# Processing: Copy of M. FIRMANSYAH PRATAMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/M. FIRMANSYAH PRATAMA.JPG (1489.94 KB)
#  --------------
#
# Processing: Copy of KHAFIZD HIDAYAT.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/KHAFIZD HIDAYAT.JPG (1364.99 KB)
#  --------------
#
# Processing: Copy of KHOIRUNNISA' INAYAH SYAFIQOH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/KHOIRUNNISA' INAYAH SYAFIQOH.JPG (1472.62 KB)
#  --------------
#
# Processing: Copy of M. NADIL ULUM ANNAFIS.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/M. NADIL ULUM ANNAFIS.JPG (1379.69 KB)
#  --------------
#
# Processing: Copy of QUROTA 'AINI RAIHANA IRFAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/QUROTA 'AINI RAIHANA IRFAN.JPG (1716.05 KB)
#  --------------
#
# Processing: Copy of OSIN SAMARINDA SILABAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/OSIN SAMARINDA SILABAN.JPG (1377.26 KB)
#  --------------
#
# Processing: Copy of ODILE FEBRIANTI GELANG.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ODILE FEBRIANTI GELANG.JPG (1600.67 KB)
#  --------------
#
# Processing: Copy of NIA DAMAYANTI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NIA DAMAYANTI.JPG (1525.29 KB)
#  --------------
#
# Processing: Copy of PANGIHUTAN IVANDER JONATAN SIHOMBING.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/PANGIHUTAN IVANDER JONATAN SIHOMBING.JPG (1337.21 KB)
#  --------------
#
# Processing: Copy of NICO HUTABARAT.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NICO HUTABARAT.JPG (1218.70 KB)
#  --------------
#
# Processing: Copy of NOVA AYU SATYAWATI SINGGIH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NOVA AYU SATYAWATI SINGGIH.JPG (1482.39 KB)
#  --------------
#
# Processing: Copy of PUTRA MAHARDIKA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/PUTRA MAHARDIKA.JPG (1459.16 KB)
#  --------------
#
# Processing: Copy of OCEANIA SEKAR NABILA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/OCEANIA SEKAR NABILA.JPG (1579.55 KB)
#  --------------
#
# Processing: Copy of NURLISTA MEYTRISIANA BENDE.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NURLISTA MEYTRISIANA BENDE.JPG (1402.13 KB)
#  --------------
#
# Processing: Copy of NI MADE YUNITYA SURASMINI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NI MADE YUNITYA SURASMINI.JPG (1479.47 KB)
#  --------------
#
# Processing: Copy of NASHWA AULIA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NASHWA AULIA.JPG (1668.51 KB)
#  --------------
#
# Processing: Copy of NAYLA SAFA AZ ZAHRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NAYLA SAFA AZ ZAHRA.JPG (1619.87 KB)
#  --------------
#
# Processing: Copy of NAFISA AULIA AKHFASY.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NAFISA AULIA AKHFASY.JPG (1556.87 KB)
#  --------------
#
# Processing: Copy of NAOMI SEPTIANI HUTABARAT.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NAOMI SEPTIANI HUTABARAT.JPG (1460.80 KB)
#  --------------
#
# Processing: Copy of NAJWAN DESTHA ASWANGGA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NAJWAN DESTHA ASWANGGA.JPG (1408.95 KB)
#  --------------
#
# Processing: Copy of NAOMI MARPAUNG.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NAOMI MARPAUNG.JPG (1460.20 KB)
#  --------------
#
# Processing: Copy of NAFI NAIFA AL FATHIN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NAFI NAIFA AL FATHIN.JPG (1412.07 KB)
#  --------------
#
# Processing: Copy of NADA NAJWA BELVANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NADA NAJWA BELVANA.JPG (1546.26 KB)
#  --------------
#
# Processing: Copy of NI PUTU NIA PRIMANDARI ARISTYA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/NI PUTU NIA PRIMANDARI ARISTYA.JPG (1492.11 KB)
#  --------------
#
# Processing: Copy of RONA FARAH FATHIYYAH RIZKY.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RONA FARAH FATHIYYAH RIZKY.JPG (1612.51 KB)
#  --------------
#
# Processing: Copy of REGY WAHYU RISTI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/REGY WAHYU RISTI.JPG (1292.98 KB)
#  --------------
#
# Processing: Copy of ROSYITA CHOIRUNISA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ROSYITA CHOIRUNISA.JPG (1597.62 KB)
#  --------------
#
# Processing: Copy of RIFQY HAFIZH NOVIAWAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RIFQY HAFIZH NOVIAWAN.JPG (1380.86 KB)
#  --------------
#
# Processing: Copy of ROJAFTUN SALWA RIHADATUL AISY.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ROJAFTUN SALWA RIHADATUL AISY.JPG (1705.15 KB)
#  --------------
#
# Processing: Copy of REBECCA INSANIA SIREGAR.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/REBECCA INSANIA SIREGAR.JPG (1540.76 KB)
#  --------------
#
# Processing: Copy of RICHA AFIYAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RICHA AFIYAH.JPG (1684.79 KB)
#  --------------
#
# Processing: Copy of RANI ALYSIA FITRI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RANI ALYSIA FITRI.JPG (1881.15 KB)
#  --------------
#
# Processing: Copy of RAYHAN AGUSTIAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RAYHAN AGUSTIAN.JPG (1440.16 KB)
#  --------------
#
# Processing: Copy of RIFQY FADLILLAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RIFQY FADLILLAH.JPG (1370.67 KB)
#  --------------
#
# Processing: Copy of RAISSYA ADHAWINA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RAISSYA ADHAWINA.JPG (1535.41 KB)
#  --------------
#
# Processing: Copy of RAHELIA NUR ARINA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RAHELIA NUR ARINA.JPG (1621.99 KB)
#  --------------
#
# Processing: Copy of RADITYA NAUFAL WIJAYA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RADITYA NAUFAL WIJAYA.JPG (1145.62 KB)
#  --------------
#
# Processing: Copy of RAMADHINA INDAH AUDESKIN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RAMADHINA INDAH AUDESKIN.JPG (1734.19 KB)
#  --------------
#
# Processing: Copy of RAISYA RAHMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RAISYA RAHMA.JPG (1454.74 KB)
#  --------------
#
# Processing: Copy of RAISYA AZZAHRA NUROHMAN.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RAISYA AZZAHRA NUROHMAN.JPG (1485.57 KB)
#  --------------
#
# Processing: Copy of RAHMAN FAIZ ARDAFFA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RAHMAN FAIZ ARDAFFA.JPG (1373.52 KB)
#  --------------
#
# Processing: Copy of RAFAH ALYAA ZAKIYYA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RAFAH ALYAA ZAKIYYA.JPG (1424.35 KB)
#  --------------
#
# Processing: Copy of RAFIQA WIDI ADHANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RAFIQA WIDI ADHANI.JPG (1675.93 KB)
#  --------------
#
# Processing: Copy of RADHO RANTE LEMBANG.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/RADHO RANTE LEMBANG.JPG (1384.03 KB)
#  --------------
#
# Processing: Copy of ZHALFA WIDYA ARFIANDIKA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ZHALFA WIDYA ARFIANDIKA.JPG (1398.14 KB)
#  --------------
#
# Processing: Copy of ZEFANYA NICHOLAS IMANUEL NITBANI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ZEFANYA NICHOLAS IMANUEL NITBANI.JPG (1421.98 KB)
#  --------------
#
# Processing: Copy of ZASKIA AMANDA NURALIMAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ZASKIA AMANDA NURALIMAH.JPG (1720.82 KB)
#  --------------
#
# Processing: Copy of ZAMZAM NURAINI ARTHA ANTIKA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/ZAMZAM NURAINI ARTHA ANTIKA.JPG (1444.57 KB)
#  --------------
#
# Processing: Copy of YOEL HOTLAND MANURUNG.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/YOEL HOTLAND MANURUNG.JPG (1445.11 KB)
#  --------------
#
# Processing: Copy of YANUAR ADHYAN BOWOLEKSONO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/YANUAR ADHYAN BOWOLEKSONO.JPG (1174.58 KB)
#  --------------
#
# Processing: Copy of WILDANUL IKRAM.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/WILDANUL IKRAM.JPG (1479.99 KB)
#  --------------
#
# Processing: Copy of WILDAN FAZA AFRIL DEWANTO.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/WILDAN FAZA AFRIL DEWANTO.JPG (1339.12 KB)
#  --------------
#
# Processing: Copy of WIFA AZALIA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/WIFA AZALIA.JPG (1692.94 KB)
#  --------------
#
# Processing: Copy of WIDYA HERNADI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/WIDYA HERNADI.JPG (1879.84 KB)
#  --------------
#
# Processing: Copy of SULTAN AHMAD ALHIDAYAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SULTAN AHMAD ALHIDAYAH.JPG (1302.53 KB)
#  --------------
#
# Processing: Copy of TAMARA MARGARETH TAMPUBOLON.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/TAMARA MARGARETH TAMPUBOLON.JPG (1500.54 KB)
#  --------------
#
# Processing: Copy of SHIFAULA TATIA MUCHTARONA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SHIFAULA TATIA MUCHTARONA.JPG (1592.76 KB)
#  --------------
#
# Processing: Copy of TYARA SALSABILA RUSTIANDI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/TYARA SALSABILA RUSTIANDI.JPG (1863.47 KB)
#  --------------
#
# Processing: Copy of UMNIYYATU NAYLI SALWA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/UMNIYYATU NAYLI SALWA.JPG (1632.33 KB)
#  --------------
#
# Processing: Copy of VYONA HAFIRISKA HABIBILLAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/VYONA HAFIRISKA HABIBILLAH.JPG (1838.96 KB)
#  --------------
#
# Processing: Copy of SULIS ESTU DIANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SULIS ESTU DIANA.JPG (1605.59 KB)
#  --------------
#
# Processing: Copy of TASYA SEPTIASA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/TASYA SEPTIASA.JPG (1523.88 KB)
#  --------------
#
# Processing: Copy of VIONA VICTORIA NOMBALA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/VIONA VICTORIA NOMBALA.JPG (1664.64 KB)
#  --------------
#
# Processing: Copy of WIDYA CANDRA TOBING.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/WIDYA CANDRA TOBING.JPG (1481.76 KB)
#  --------------
#
# Processing: Copy of SHEEREN DWI LEVANI ZAHRA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SHEEREN DWI LEVANI ZAHRA.JPG (1417.25 KB)
#  --------------
#
# Processing: Copy of SAMUEL GILBERT.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SAMUEL GILBERT.JPG (1240.84 KB)
#  --------------
#
# Processing: Copy of SALMA AN NABILAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SALMA AN NABILAH.JPG (1676.53 KB)
#  --------------
#
# Processing: Copy of SHERLY MUTIARA RHOMADHONI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SHERLY MUTIARA RHOMADHONI.JPG (1571.49 KB)
#  --------------
#
# Processing: Copy of SALSABILA ANNISA RAHMA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SALSABILA ANNISA RAHMA.JPG (1681.98 KB)
#  --------------
#
# Processing: Copy of SATRIAJI ILHAM AHZAR RR..JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SATRIAJI ILHAM AHZAR RR..JPG (1529.68 KB)
#  --------------
#
# Processing: Copy of SAKINNAH SALSABILLA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SAKINNAH SALSABILLA.JPG (1818.80 KB)
#  --------------
#
# Processing: Copy of SALMA AZIZAH.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SALMA AZIZAH.JPG (1928.82 KB)
#  --------------
#
# Processing: Copy of SABILA RIZQIA RAHMADINI.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SABILA RIZQIA RAHMADINI.JPG (1610.02 KB)
#  --------------
#
# Processing: Copy of SAFIQ RAHMAN MAULANA.JPG
# ✅ Saved: /content/drive/MyDrive/testing_cut_photo/crop_result/day_2/SAFIQ RAHMAN MAULANA.JPG (1290.69 KB)
#  --------------
